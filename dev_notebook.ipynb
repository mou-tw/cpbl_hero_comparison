# %%
import pandas as pd
import numpy as np
import click

# %%
hitter_atk_df = pd.read_csv('docs/hitter_atk.csv')

# %%
hitter_atk_df.name = hitter_atk_df.name.str.extract(r'(\D+)',expand=False)

# %%
target_player = hitter_atk_df.loc[0]

# %%
# 取得該年度的有效資料，有效資料的定義為球員的打席需要大於30場
py = target_player.play_year
t_df = hitter_atk_df[hitter_atk_df.play_year== py][list(hitter_atk_df)[7:]]
t_df = t_df[t_df.打席>30]
t_df_50 = pd.DataFrame(t_df.median())

# %%
d_cols = ['被三振','雙殺打',]
a_cols = ['出賽數','打席','打數','打點','得分','安打','一安','二安','三安','全壘打','壘打數','盜壘','上壘率','長打率','打擊率',
         '四壞','故四','盜壘率', '整體攻擊指數']
n_cols = ['犧短','犧飛','死球','盜壘刺','滾地出局','高飛出局','滾飛出局比',]

t_agg_lst = []
for i in list(hitter_atk_df)[7:]:
    if i in a_cols or i in n_cols:
        t_agg_lst.append(t_df[i].quantile(0.75))
    else :
        t_agg_lst.append(t_df[i].quantile(0.25))

# %%
t_df_75 = pd.DataFrame(t_agg_lst,index= list(hitter_atk_df)[7:])

# %%
agg_t_df = pd.concat([target_player[7:],t_df_50,t_df_75],axis=1)

# %%
agg_t_df.columns = ['原始數據','該年度球員中位數成績','該年度球員75分百位數成績']

# %%
org_col , compare_col = ['原始數據'] , ['該年度球員中位數成績','該年度球員75分百位數成績']
for i in org_col:
    for j in compare_col:
        tmp_lst = []
        org_s = agg_t_df[i]
        com_s = agg_t_df[j]
        for d in org_s.index:
            if d in d_cols:
                tmp_lst.append( "lose" if org_s[d] > com_s[d] else "win" )
            elif d in a_cols:
                tmp_lst.append( "win" if org_s[d] > com_s[d] else "lose" )
            elif d in n_cols:
                tmp_lst.append(np.NaN)
        print(pd.DataFrame(tmp_lst, index= list(hitter_atk_df)[7:]))
        agg_t_df[f'{i}_{j}比較'] = pd.DataFrame(tmp_lst, index= list(hitter_atk_df)[7:])
# Out:
#            0
# 出賽數      win
# 打席       win
# 打數       win
# 打點       win
# 得分       win
# 安打       win
# 一安       win
# 二安       win
# 三安       win
# 全壘打      win
# 壘打數      win
# 被三振     lose
# 盜壘       win
# 上壘率     lose
# 長打率      win
# 打擊率     lose
# 雙殺打     lose
# 犧短       NaN
# 犧飛       NaN
# 四壞       win
# 故四      lose
# 死球       NaN
# 盜壘刺      NaN
# 滾地出局     NaN
# 高飛出局     NaN
# 滾飛出局比    NaN
# 盜壘率     lose
# 整體攻擊指數   win
#            0
# 出賽數     lose
# 打席      lose
# 打數       win
# 打點       win
# 得分      lose
# 安打      lose
# 一安      lose
# 二安      lose
# 三安      lose
# 全壘打      win
# 壘打數      win
# 被三振     lose
# 盜壘      lose
# 上壘率     lose
# 長打率     lose
# 打擊率     lose
# 雙殺打     lose
# 犧短       NaN
# 犧飛       NaN
# 四壞      lose
# 故四      lose
# 死球       NaN
# 盜壘刺      NaN
# 滾地出局     NaN
# 高飛出局     NaN
# 滾飛出局比    NaN
# 盜壘率     lose
# 整體攻擊指數  lose

# %%
agg_t_df = agg_t_df.drop(['該年度球員中位數成績','該年度球員75分百位數成績'],1)

# %%
agg_t_df.index.name = '數據項目'
agg_t_df.columns.name = '數據類型'

# %%
o_df = pd.concat([target_player[target_player.index[:7]],target_player[target_player.index[:7]],target_player[target_player.index[:7]]] ,1)
o_df.columns = agg_t_df.columns

# %%
f_agg_lst = pd.concat([o_df,agg_t_df])

# %%
f_agg_lst.index.name = '數據項目'
f_agg_lst.columns.name = '數據類型'

# %%
target_player.
# Out:
# name           丘昌榮
# ages            31
# team            誠泰
# play_year     2003
# country       中華民國
# 打               右打
# 投               右投
# 出賽數             91
# 打席             331
# 打數             304
# 打點              44
# 得分              23
# 安打              73
# 一安              50
# 二安              14
# 三安               2
# 全壘打              7
# 壘打數            112
# 被三振             82
# 盜壘               4
# 上壘率          0.288
# 長打率          0.368
# 打擊率           0.24
# 雙殺打              7
# 犧短               1
# 犧飛               4
# 四壞              21
# 故四               0
# 死球               1
# 盜壘刺              4
# 滾地出局            76
# 高飛出局            78
# 滾飛出局比        0.974
# 盜壘率            0.5
# 整體攻擊指數       0.656
# Name: 0, dtype: object

# %%
f_agg_lst.to_csv(target_player.nm)
# Out:
# 數據類型        原始數據 原始數據_該年度球員中位數成績比較 原始數據_該年度球員75分百位數成績比較
# 數據項目
# name         丘昌榮               丘昌榮                  丘昌榮
# ages          31                31                   31
# team          誠泰                誠泰                   誠泰
# play_year   2003              2003                 2003
# country     中華民國              中華民國                 中華民國
# 打             右打                右打                   右打
# 投             右投                右投                   右投
# 出賽數           91               win                 lose
# 打席           331               win                 lose
# 打數           304               win                  win
# 打點            44               win                  win
# 得分            23               win                 lose
# 安打            73               win                 lose
# 一安            50               win                 lose
# 二安            14               win                 lose
# 三安             2               win                 lose
# 全壘打            7               win                  win
# 壘打數          112               win                  win
# 被三振           82              lose                 lose
# 盜壘             4               win                 lose
# 上壘率        0.288              lose                 lose
# 長打率        0.368               win                 lose
# 打擊率         0.24              lose                 lose
# 雙殺打            7              lose                 lose
# 犧短             1               NaN                  NaN
# 犧飛             4               NaN                  NaN
# 四壞            21               win                 lose
# 故四             0              lose                 lose
# 死球             1               NaN                  NaN
# 盜壘刺            4               NaN                  NaN
# 滾地出局          76               NaN                  NaN
# 高飛出局          78               NaN                  NaN
# 滾飛出局比      0.974               NaN                  NaN
# 盜壘率          0.5              lose                 lose
# 整體攻擊指數     0.656               win                 lose

# %%
tmp_df = pd.read_csv('docs/陳金鋒_2006.csv')

# %%
tmp_df
# Out:
#          數據項目    原始數據 原始數據_該年度球員中位數成績比較 原始數據_該年度球員75分百位數成績比較
# 0        name     陳金鋒               陳金鋒                  陳金鋒
# 1        ages      29                29                   29
# 2        team  Lamigo            Lamigo               Lamigo
# 3   play_year    2006              2006                 2006
# 4     country    中華民國              中華民國                 中華民國
# 5           打      右打                右打                   右打
# 6           投      右投                右投                   右投
# 7         出賽數    91.0               win                  win
# 8          打席   398.0               win                  win
# 9          打數   344.0               win                  win
# 10         打點    81.0               win                  win
# 11         得分    76.0               win                  win
# 12         安打   109.0               win                  win
# 13         一安    67.0               win                  win
# 14         二安    21.0               win                  win
# 15         三安     0.0              lose                 lose
# 16        全壘打    21.0               win                  win
# 17        壘打數   193.0               win                  win
# 18        被三振    72.0              lose                 lose
# 19         盜壘    20.0               win                  win
# 20        上壘率   0.385               win                  win
# 21        長打率   0.561               win                  win
# 22        打擊率   0.317               win                  win
# 23        雙殺打     8.0              lose                 lose
# 24         犧短     0.0               NaN                  NaN
# 25         犧飛     5.0               NaN                  NaN
# 26         四壞    36.0               win                  win
# 27         故四     8.0               win                  win
# 28         死球     5.0               NaN                  NaN
# 29        盜壘刺     1.0               NaN                  NaN
# 30       滾地出局    81.0               NaN                  NaN
# 31       高飛出局    87.0               NaN                  NaN
# 32      滾飛出局比   0.931               NaN                  NaN
# 33        盜壘率    0.95               win                  win
# 34     整體攻擊指數   0.946               win                  win
